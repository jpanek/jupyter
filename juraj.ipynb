# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.normal(loc=0,scale=1,size=1000)
plt.hist(x,bins=20)
plt.grid(True)
plt.show()

# %%
x = np.linspace(-5,5)
y = np.cos(x)
plt.plot(x,y)
plt.show()
